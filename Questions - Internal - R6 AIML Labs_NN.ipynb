# %% [markdown]
# # The Iris Dataset
# The data set consists of 50 samples from each of three species of Iris (Iris setosa, Iris virginica and Iris versicolor). Four features were measured from each sample: the length and the width of the sepals and petals, in centimeters.
#
# The dataset contains a set of 150 records under five attributes - petal length, petal width, sepal length, sepal width and species.

# %% [markdown]
# ### Specifying the TensorFlow version
# Running `import tensorflow` will import the default version (currently 1.x). You can use 2.x by running a cell with the `tensorflow_version` magic **before** you run `import tensorflow`.

# %%
# %tensorflow_version 2.x

# %% [markdown]
# ### Import TensorFlow
# Once you have specified a version via this magic, you can run `import tensorflow` as normal and verify which version was imported as follows:

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.1.0

# %% [markdown]
# ### Set random seed

# %%
tf.random.set_seed(42)

# %% [markdown]
# ## Question 1

# %% [markdown]
# ### Import dataset
# - Import iris dataset
# - Import the dataset using sklearn library

# %%
#from google.colab import files
#uploaded = files.upload()
from sklearn.datasets import load_iris
df=load_iris()

# %%
import pandas as pd
import numpy as np

# %%
type(df)
# Out:
# sklearn.utils.Bunch

# %% [markdown]
# ## Question 2

# %% [markdown]
# ### Get features and label from the dataset in separate variable
# - you can get the features using .data method
# - you can get the features using .target method

# %%
X=df.data
Y=df.target

# %% [markdown]
# ## Question 3

# %% [markdown]
# ### Create train and test data
# - use train_test_split to get train and test set
# - set a random_state
# - test_size: 0.25

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.25,random_state=100)

# %%
X_train.shape
# Out:
# (112, 4)

# %% [markdown]
# ## Question 4

# %% [markdown]
# ### One-hot encode the labels
# - convert class vectors (integers) to binary class matrix
# - convert labels
# - number of classes: 3
# - we are doing this to use categorical_crossentropy as loss

# %%
from tensorflow.keras.utils import to_categorical

# %%
Y_train=to_categorical(Y_train,3)
Y_test=to_categorical(Y_test,3)

# %% [markdown]
# ## Question 5

# %% [markdown]
# ### Initialize a sequential model
# - Define a sequential model

# %%
model=tf.keras.Sequential()

# %% [markdown]
# ## Question 6

# %% [markdown]
# ### Add a layer
# - Use Dense Layer  with input shape of 4 (according to the feature set) and number of outputs set to 3
# - Apply Softmax on Dense Layer outputs

# %%
from tensorflow.keras.layers import Dense

# %%
model.add(Dense(4, activation='relu', input_shape=(4,)))
model.add(Dense(4, activation='relu'))
model.add(Dense(3, activation='softmax'))

# %% [markdown]
# ## Question 7

# %% [markdown]
# ### Compile the model
# - Use SGD as Optimizer
# - Use categorical_crossentropy as loss function
# - Use accuracy as metrics

# %%
model.compile(loss='categorical_crossentropy',
#model.compile(loss='binary_crossentropy',
              optimizer='SGD',
              metrics=['accuracy'])

# %% [markdown]
# ## Question 8

# %% [markdown]
# ### Summarize the model
# - Check model layers
# - Understand number of trainable parameters

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 4)                 20
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 20
# _________________________________________________________________
# dense_5 (Dense)              (None, 3)                 15
# =================================================================
# Total params: 55
# Trainable params: 55
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Question 9

# %% [markdown]
# ### Fit the model
# - Give train data as training features and labels
# - Epochs: 100
# - Give validation data as testing features and labels

# %%
model.fit(X_train,Y_train,validation_data=(X_test,Y_test),epochs=100)
# Out:
# Train on 112 samples, validate on 38 samples
# Epoch 1/100
# 112/112 [==============================] - 0s 3ms/sample - loss: 1.4860 - accuracy: 0.3571 - val_loss: 1.4633 - val_accuracy: 0.2632
# Epoch 2/100
# 112/112 [==============================] - 0s 221us/sample - loss: 1.3181 - accuracy: 0.3571 - val_loss: 1.3477 - val_accuracy: 0.2632
# Epoch 3/100
# 112/112 [==============================] - 0s 223us/sample - loss: 1.2429 - accuracy: 0.3571 - val_loss: 1.2830 - val_accuracy: 0.2632
# Epoch 4/100
# 112/112 [==============================] - 0s 248us/sample - loss: 1.1956 - accuracy: 0.3571 - val_loss: 1.2231 - val_accuracy: 0.2632
# Epoch 5/100
# 112/112 [==============================] - 0s 233us/sample - loss: 1.1575 - accuracy: 0.3571 - val_loss: 1.1847 - val_accuracy: 0.2632
# Epoch 6/100
# 112/112 [==============================] - 0s 168us/sample - loss: 1.1330 - accuracy: 0.3571 - val_loss: 1.1590 - val_accuracy: 0.2632
# Epoch 7/100
# 112/112 [==============================] - 0s 187us/sample - loss: 1.1183 - accuracy: 0.3571 - val_loss: 1.1397 - val_accuracy: 0.2632
# Epoch 8/100
# 112/112 [==============================] - 0s 160us/sample - loss: 1.1074 - accuracy: 0.3571 - val_loss: 1.1233 - val_accuracy: 0.2632
# Epoch 9/100
# 112/112 [==============================] - 0s 195us/sample - loss: 1.0971 - accuracy: 0.3571 - val_loss: 1.1107 - val_accuracy: 0.2632
# Epoch 10/100
# 112/112 [==============================] - 0s 218us/sample - loss: 1.0897 - accuracy: 0.3571 - val_loss: 1.1004 - val_accuracy: 0.2632
# Epoch 11/100
# 112/112 [==============================] - 0s 239us/sample - loss: 1.0856 - accuracy: 0.3393 - val_loss: 1.0970 - val_accuracy: 0.2632
# Epoch 12/100
# 112/112 [==============================] - 0s 245us/sample - loss: 1.0822 - accuracy: 0.3571 - val_loss: 1.0920 - val_accuracy: 0.2105
# Epoch 13/100
# 112/112 [==============================] - 0s 228us/sample - loss: 1.0786 - accuracy: 0.2946 - val_loss: 1.0867 - val_accuracy: 0.0789
# Epoch 14/100
# 112/112 [==============================] - 0s 267us/sample - loss: 1.0758 - accuracy: 0.2232 - val_loss: 1.0843 - val_accuracy: 0.2632
# Epoch 15/100
# 112/112 [==============================] - 0s 198us/sample - loss: 1.0746 - accuracy: 0.1429 - val_loss: 1.0810 - val_accuracy: 0.3684
# Epoch 16/100
# 112/112 [==============================] - 0s 179us/sample - loss: 1.0720 - accuracy: 0.3214 - val_loss: 1.0785 - val_accuracy: 0.3684
# Epoch 17/100
# 112/112 [==============================] - 0s 241us/sample - loss: 1.0700 - accuracy: 0.3214 - val_loss: 1.0767 - val_accuracy: 0.3684
# Epoch 18/100
# 112/112 [==============================] - 0s 233us/sample - loss: 1.0690 - accuracy: 0.3214 - val_loss: 1.0726 - val_accuracy: 0.3684
# Epoch 19/100
# 112/112 [==============================] - 0s 265us/sample - loss: 1.0663 - accuracy: 0.3214 - val_loss: 1.0708 - val_accuracy: 0.3684
# Epoch 20/100
# 112/112 [==============================] - 0s 191us/sample - loss: 1.0648 - accuracy: 0.3214 - val_loss: 1.0698 - val_accuracy: 0.3684
# Epoch 21/100
# 112/112 [==============================] - 0s 188us/sample - loss: 1.0629 - accuracy: 0.3214 - val_loss: 1.0668 - val_accuracy: 0.3684
# Epoch 22/100
# 112/112 [==============================] - 0s 171us/sample - loss: 1.0618 - accuracy: 0.3214 - val_loss: 1.0666 - val_accuracy: 0.3684
# Epoch 23/100
# 112/112 [==============================] - 0s 187us/sample - loss: 1.0606 - accuracy: 0.3214 - val_loss: 1.0631 - val_accuracy: 0.3684
# Epoch 24/100
# 112/112 [==============================] - 0s 181us/sample - loss: 1.0586 - accuracy: 0.3214 - val_loss: 1.0611 - val_accuracy: 0.3684
# Epoch 25/100
# 112/112 [==============================] - 0s 207us/sample - loss: 1.0569 - accuracy: 0.3214 - val_loss: 1.0602 - val_accuracy: 0.3684
# Epoch 26/100
# 112/112 [==============================] - 0s 187us/sample - loss: 1.0552 - accuracy: 0.3214 - val_loss: 1.0588 - val_accuracy: 0.3684
# Epoch 27/100
# 112/112 [==============================] - 0s 179us/sample - loss: 1.0541 - accuracy: 0.3214 - val_loss: 1.0572 - val_accuracy: 0.3684
# Epoch 28/100
# 112/112 [==============================] - 0s 157us/sample - loss: 1.0518 - accuracy: 0.3214 - val_loss: 1.0551 - val_accuracy: 0.3684
# Epoch 29/100
# 112/112 [==============================] - 0s 159us/sample - loss: 1.0503 - accuracy: 0.3214 - val_loss: 1.0528 - val_accuracy: 0.3684
# Epoch 30/100
# 112/112 [==============================] - 0s 162us/sample - loss: 1.0485 - accuracy: 0.3214 - val_loss: 1.0504 - val_accuracy: 0.3684
# Epoch 31/100
# 112/112 [==============================] - 0s 191us/sample - loss: 1.0477 - accuracy: 0.3214 - val_loss: 1.0475 - val_accuracy: 0.3684
# Epoch 32/100
# 112/112 [==============================] - 0s 169us/sample - loss: 1.0449 - accuracy: 0.3214 - val_loss: 1.0465 - val_accuracy: 0.3684
# Epoch 33/100
# 112/112 [==============================] - 0s 169us/sample - loss: 1.0440 - accuracy: 0.3214 - val_loss: 1.0453 - val_accuracy: 0.3684
# Epoch 34/100
# 112/112 [==============================] - 0s 184us/sample - loss: 1.0415 - accuracy: 0.3214 - val_loss: 1.0438 - val_accuracy: 0.3684
# Epoch 35/100
# 112/112 [==============================] - 0s 189us/sample - loss: 1.0393 - accuracy: 0.3214 - val_loss: 1.0433 - val_accuracy: 0.3684
# Epoch 36/100
# 112/112 [==============================] - 0s 167us/sample - loss: 1.0372 - accuracy: 0.3214 - val_loss: 1.0408 - val_accuracy: 0.3684
# Epoch 37/100
# 112/112 [==============================] - 0s 167us/sample - loss: 1.0351 - accuracy: 0.3214 - val_loss: 1.0370 - val_accuracy: 0.3684
# Epoch 38/100
# 112/112 [==============================] - 0s 172us/sample - loss: 1.0336 - accuracy: 0.3214 - val_loss: 1.0348 - val_accuracy: 0.3684
# Epoch 39/100
# 112/112 [==============================] - 0s 160us/sample - loss: 1.0309 - accuracy: 0.3214 - val_loss: 1.0335 - val_accuracy: 0.3684
# Epoch 40/100
# 112/112 [==============================] - 0s 158us/sample - loss: 1.0286 - accuracy: 0.3214 - val_loss: 1.0315 - val_accuracy: 0.3684
# Epoch 41/100
# 112/112 [==============================] - 0s 165us/sample - loss: 1.0272 - accuracy: 0.3214 - val_loss: 1.0286 - val_accuracy: 0.3684
# Epoch 42/100
# 112/112 [==============================] - 0s 172us/sample - loss: 1.0240 - accuracy: 0.3214 - val_loss: 1.0266 - val_accuracy: 0.3684
# Epoch 43/100
# 112/112 [==============================] - 0s 168us/sample - loss: 1.0214 - accuracy: 0.3214 - val_loss: 1.0235 - val_accuracy: 0.3684
# Epoch 44/100
# 112/112 [==============================] - 0s 173us/sample - loss: 1.0193 - accuracy: 0.3214 - val_loss: 1.0218 - val_accuracy: 0.3684
# Epoch 45/100
# 112/112 [==============================] - 0s 182us/sample - loss: 1.0174 - accuracy: 0.3214 - val_loss: 1.0195 - val_accuracy: 0.3684
# Epoch 46/100
# 112/112 [==============================] - 0s 179us/sample - loss: 1.0140 - accuracy: 0.3214 - val_loss: 1.0166 - val_accuracy: 0.3684
# Epoch 47/100
# 112/112 [==============================] - 0s 182us/sample - loss: 1.0120 - accuracy: 0.3214 - val_loss: 1.0129 - val_accuracy: 0.3684
# Epoch 48/100
# 112/112 [==============================] - 0s 161us/sample - loss: 1.0100 - accuracy: 0.3214 - val_loss: 1.0111 - val_accuracy: 0.3684
# Epoch 49/100
# 112/112 [==============================] - 0s 173us/sample - loss: 1.0060 - accuracy: 0.3214 - val_loss: 1.0083 - val_accuracy: 0.3684
# Epoch 50/100
# 112/112 [==============================] - 0s 165us/sample - loss: 1.0032 - accuracy: 0.3214 - val_loss: 1.0040 - val_accuracy: 0.3684
# Epoch 51/100
# 112/112 [==============================] - 0s 138us/sample - loss: 1.0006 - accuracy: 0.3214 - val_loss: 1.0015 - val_accuracy: 0.3684
# Epoch 52/100
# 112/112 [==============================] - 0s 159us/sample - loss: 0.9971 - accuracy: 0.3214 - val_loss: 0.9968 - val_accuracy: 0.3684
# Epoch 53/100
# 112/112 [==============================] - 0s 186us/sample - loss: 0.9941 - accuracy: 0.3214 - val_loss: 0.9924 - val_accuracy: 0.3684
# Epoch 54/100
# 112/112 [==============================] - 0s 183us/sample - loss: 0.9905 - accuracy: 0.3214 - val_loss: 0.9900 - val_accuracy: 0.3684
# Epoch 55/100
# 112/112 [==============================] - 0s 200us/sample - loss: 0.9873 - accuracy: 0.3214 - val_loss: 0.9849 - val_accuracy: 0.3684
# Epoch 56/100
# 112/112 [==============================] - 0s 184us/sample - loss: 0.9835 - accuracy: 0.3214 - val_loss: 0.9820 - val_accuracy: 0.3684
# Epoch 57/100
# 112/112 [==============================] - 0s 185us/sample - loss: 0.9811 - accuracy: 0.3304 - val_loss: 0.9797 - val_accuracy: 0.3684
# Epoch 58/100
# 112/112 [==============================] - 0s 245us/sample - loss: 0.9759 - accuracy: 0.3304 - val_loss: 0.9764 - val_accuracy: 0.3684
# Epoch 59/100
# 112/112 [==============================] - 0s 198us/sample - loss: 0.9720 - accuracy: 0.3304 - val_loss: 0.9714 - val_accuracy: 0.3684
# Epoch 60/100
# 112/112 [==============================] - 0s 234us/sample - loss: 0.9690 - accuracy: 0.3304 - val_loss: 0.9661 - val_accuracy: 0.3684
# Epoch 61/100
# 112/112 [==============================] - 0s 251us/sample - loss: 0.9636 - accuracy: 0.3482 - val_loss: 0.9603 - val_accuracy: 0.3947
# Epoch 62/100
# 112/112 [==============================] - 0s 214us/sample - loss: 0.9604 - accuracy: 0.3482 - val_loss: 0.9535 - val_accuracy: 0.3947
# Epoch 63/100
# 112/112 [==============================] - 0s 187us/sample - loss: 0.9547 - accuracy: 0.3571 - val_loss: 0.9482 - val_accuracy: 0.4211
# Epoch 64/100
# 112/112 [==============================] - 0s 238us/sample - loss: 0.9499 - accuracy: 0.3661 - val_loss: 0.9415 - val_accuracy: 0.4474
# Epoch 65/100
# 112/112 [==============================] - 0s 235us/sample - loss: 0.9451 - accuracy: 0.4375 - val_loss: 0.9364 - val_accuracy: 0.4737
# Epoch 66/100
# 112/112 [==============================] - 0s 197us/sample - loss: 0.9395 - accuracy: 0.4375 - val_loss: 0.9310 - val_accuracy: 0.4737
# Epoch 67/100
# 112/112 [==============================] - 0s 180us/sample - loss: 0.9355 - accuracy: 0.4643 - val_loss: 0.9239 - val_accuracy: 0.5000
# Epoch 68/100
# 112/112 [==============================] - 0s 201us/sample - loss: 0.9301 - accuracy: 0.5357 - val_loss: 0.9180 - val_accuracy: 0.5526
# Epoch 69/100
# 112/112 [==============================] - 0s 190us/sample - loss: 0.9232 - accuracy: 0.5536 - val_loss: 0.9124 - val_accuracy: 0.5789
# Epoch 70/100
# 112/112 [==============================] - 0s 264us/sample - loss: 0.9174 - accuracy: 0.5625 - val_loss: 0.9046 - val_accuracy: 0.6579
# Epoch 71/100
# 112/112 [==============================] - 0s 193us/sample - loss: 0.9112 - accuracy: 0.5804 - val_loss: 0.8965 - val_accuracy: 0.6842
# Epoch 72/100
# 112/112 [==============================] - 0s 196us/sample - loss: 0.9045 - accuracy: 0.5893 - val_loss: 0.8892 - val_accuracy: 0.7105
# Epoch 73/100
# 112/112 [==============================] - 0s 195us/sample - loss: 0.8988 - accuracy: 0.6161 - val_loss: 0.8819 - val_accuracy: 0.7105
# Epoch 74/100
# 112/112 [==============================] - 0s 175us/sample - loss: 0.8916 - accuracy: 0.6161 - val_loss: 0.8752 - val_accuracy: 0.7368
# Epoch 75/100
# 112/112 [==============================] - 0s 183us/sample - loss: 0.8854 - accuracy: 0.6250 - val_loss: 0.8679 - val_accuracy: 0.7368
# Epoch 76/100
# 112/112 [==============================] - 0s 257us/sample - loss: 0.8794 - accuracy: 0.6250 - val_loss: 0.8622 - val_accuracy: 0.7368
# Epoch 77/100
# 112/112 [==============================] - 0s 201us/sample - loss: 0.8733 - accuracy: 0.6250 - val_loss: 0.8551 - val_accuracy: 0.7368
# Epoch 78/100
# 112/112 [==============================] - 0s 214us/sample - loss: 0.8679 - accuracy: 0.6250 - val_loss: 0.8484 - val_accuracy: 0.7368
# Epoch 79/100
# 112/112 [==============================] - 0s 236us/sample - loss: 0.8625 - accuracy: 0.6250 - val_loss: 0.8403 - val_accuracy: 0.7368
# Epoch 80/100
# 112/112 [==============================] - 0s 185us/sample - loss: 0.8564 - accuracy: 0.6250 - val_loss: 0.8352 - val_accuracy: 0.7368
# Epoch 81/100
# 112/112 [==============================] - 0s 232us/sample - loss: 0.8514 - accuracy: 0.6250 - val_loss: 0.8298 - val_accuracy: 0.7368
# Epoch 82/100
# 112/112 [==============================] - 0s 208us/sample - loss: 0.8467 - accuracy: 0.6339 - val_loss: 0.8244 - val_accuracy: 0.7368
# Epoch 83/100
# 112/112 [==============================] - 0s 171us/sample - loss: 0.8419 - accuracy: 0.6339 - val_loss: 0.8185 - val_accuracy: 0.7368
# Epoch 84/100
# 112/112 [==============================] - 0s 236us/sample - loss: 0.8369 - accuracy: 0.6339 - val_loss: 0.8120 - val_accuracy: 0.7368
# Epoch 85/100
# 112/112 [==============================] - 0s 196us/sample - loss: 0.8325 - accuracy: 0.6250 - val_loss: 0.8060 - val_accuracy: 0.7368
# Epoch 86/100
# 112/112 [==============================] - 0s 178us/sample - loss: 0.8279 - accuracy: 0.6250 - val_loss: 0.8017 - val_accuracy: 0.7368
# Epoch 87/100
# 112/112 [==============================] - 0s 166us/sample - loss: 0.8236 - accuracy: 0.6250 - val_loss: 0.7992 - val_accuracy: 0.7368
# Epoch 88/100
# 112/112 [==============================] - 0s 173us/sample - loss: 0.8182 - accuracy: 0.6250 - val_loss: 0.7948 - val_accuracy: 0.7368
# Epoch 89/100
# 112/112 [==============================] - 0s 232us/sample - loss: 0.8146 - accuracy: 0.6339 - val_loss: 0.7896 - val_accuracy: 0.7368
# Epoch 90/100
# 112/112 [==============================] - 0s 199us/sample - loss: 0.8103 - accuracy: 0.6250 - val_loss: 0.7854 - val_accuracy: 0.7368
# Epoch 91/100
# 112/112 [==============================] - 0s 185us/sample - loss: 0.8061 - accuracy: 0.6339 - val_loss: 0.7803 - val_accuracy: 0.7368
# Epoch 92/100
# 112/112 [==============================] - 0s 211us/sample - loss: 0.8020 - accuracy: 0.6250 - val_loss: 0.7765 - val_accuracy: 0.7368
# Epoch 93/100
# 112/112 [==============================] - 0s 234us/sample - loss: 0.7990 - accuracy: 0.6250 - val_loss: 0.7720 - val_accuracy: 0.7368
# Epoch 94/100
# 112/112 [==============================] - 0s 243us/sample - loss: 0.7942 - accuracy: 0.6339 - val_loss: 0.7682 - val_accuracy: 0.7368
# Epoch 95/100
# 112/112 [==============================] - 0s 189us/sample - loss: 0.7906 - accuracy: 0.6429 - val_loss: 0.7634 - val_accuracy: 0.7368
# Epoch 96/100
# 112/112 [==============================] - 0s 203us/sample - loss: 0.7870 - accuracy: 0.6339 - val_loss: 0.7596 - val_accuracy: 0.7368
# Epoch 97/100
# 112/112 [==============================] - 0s 188us/sample - loss: 0.7840 - accuracy: 0.6429 - val_loss: 0.7542 - val_accuracy: 0.7368
# Epoch 98/100
# 112/112 [==============================] - 0s 193us/sample - loss: 0.7803 - accuracy: 0.6339 - val_loss: 0.7520 - val_accuracy: 0.7368
# Epoch 99/100
# 112/112 [==============================] - 0s 221us/sample - loss: 0.7768 - accuracy: 0.6518 - val_loss: 0.7469 - val_accuracy: 0.7368
# Epoch 100/100
# 112/112 [==============================] - 0s 262us/sample - loss: 0.7736 - accuracy: 0.6339 - val_loss: 0.7459 - val_accuracy: 0.7368

# %% [markdown]
# ## Question 10

# %% [markdown]
# ### Make predictions
# - Predict labels on one row

# %%
model.predict(X_test[0:1])
# Out:
# array([[0.04311325, 0.35139015, 0.6054966 ]], dtype=float32)

# %% [markdown]
# ### Compare the prediction with actual label
# - Print the same row as done in the previous step but of actual labels

# %%
Y_test[0:1]
# Out:
# array([[0., 0., 1.]], dtype=float32)

# %% [markdown]
# ---

# %% [markdown]
# # Stock prices dataset
# The data is of tock exchange's stock listings for each trading day of 2010 to 2016.
#
# ## Description
# A brief description of columns.
# - open: The opening market price of the equity symbol on the date
# - high: The highest market price of the equity symbol on the date
# - low: The lowest recorded market price of the equity symbol on the date
# - close: The closing recorded price of the equity symbol on the date
# - symbol: Symbol of the listed company
# - volume: Total traded volume of the equity symbol on the date
# - date: Date of record

# %% [markdown]
# ### Specifying the TensorFlow version
# Running `import tensorflow` will import the default version (currently 1.x). You can use 2.x by running a cell with the `tensorflow_version` magic **before** you run `import tensorflow`.

# %%
# %tensorflow_version 2.x

# %% [markdown]
# ### Import TensorFlow
# Once you have specified a version via this magic, you can run `import tensorflow` as normal and verify which version was imported as follows:

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.1.0

# %% [markdown]
# ### Set random seed

# %%
tf.random.set_seed(42)

# %% [markdown]
# ## Question 1

# %% [markdown]
# ### Load the data
# - load the csv file and read it using pandas
# - file name is prices.csv

# %%
# run this cell to upload file if you are using google colab
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-796f9f52-c080-4574-b8bb-17ee93120729" name="files[]" multiple disabled />
#      <output id="result-796f9f52-c080-4574-b8bb-17ee93120729">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving prices.csv to prices.csv

# %%
import pandas as pd
import numpy as np

df_price=pd.read_csv("prices.csv")

# %%
df_price.head()
#df_price.shape
# Out:
#                   date symbol        open  ...         low        high     volume
# 0  2016-01-05 00:00:00   WLTW  123.430000  ...  122.309998  126.250000  2163600.0
# 1  2016-01-06 00:00:00   WLTW  125.239998  ...  119.940002  125.540001  2386400.0
# 2  2016-01-07 00:00:00   WLTW  116.379997  ...  114.930000  119.739998  2489500.0
# 3  2016-01-08 00:00:00   WLTW  115.480003  ...  113.500000  117.440002  2006300.0
# 4  2016-01-11 00:00:00   WLTW  117.010002  ...  114.089996  117.330002  1408600.0
#
# [5 rows x 7 columns]

# %% [markdown]
# ## Question 2

# %% [markdown]
# ### Drop columnns
# - drop "date" and "symbol" column from the data

# %%
df_price=df_price.drop(['date','symbol'],axis=1)

# %%
df_price.shape
# Out:
# (851264, 5)

# %% [markdown]
# ## Question 3

# %% [markdown]
# ### Take initial rows
# - Take first 1000 rows from the data
# - This step is done to make the execution faster

# %%
df_price=df_price[0:1000]
df_price.shape
# Out:
# (1000, 5)

# %% [markdown]
# ## Question 4

# %% [markdown]
# ### Get features and label from the dataset in separate variable
# - Take "open", "close", "low", "high" columns as features
# - Take "volume" column as label
# - Normalize label column by dividing it with 1000000

# %%
X=df_price[["open", "close", "low", "high"]]
y=df_price['volume']
y=y/1000000

# %%
X.dtypes
# Out:
# open     float64
# close    float64
# low      float64
# high     float64
# dtype: object

# %% [markdown]
# ## Question 5

# %% [markdown]
# ### Convert data
# - Convert features and labels to numpy array
# - Convert their data type to "float32"

# %%
X=np.array(X)
Y=np.array(y)
X=X.astype("float32")
Y=Y.astype("float32")

# %% [markdown]
# ## Question 6

# %% [markdown]
# ### Normalize data
# - Normalize features
# - Use tf.math.l2_normalize to normalize features
# - You can read more about it here https://www.tensorflow.org/api_docs/python/tf/math/l2_normalize

# %%
X=tf.math.l2_normalize(
    X,
    axis=None,
    epsilon=1e-12,
    name=None
)

# %% [markdown]
# ## Question 7

# %% [markdown]
# ### Define weight and bias
# - Initialize weight and bias with tf.zeros
# - tf.zeros is an initializer that generates tensors initialized to 0
# - Specify the value for shape

# %%
w=tf.zeros(shape=(4,1))
b=tf.zeros(shape=(1))

# %% [markdown]
# ## Question 8

# %% [markdown]
# ### Get prediction
# - Define a function to get prediction
# - Approach: prediction = (X * W) + b; here is X is features

# %%
@tf.function 
def prediction(features,w,b):
  y_pred=tf.add(tf.matmul(features,w),b)
  return y_pred

# %% [markdown]
# ### Calculate loss
# - Calculate loss using predictions
# - Define a function to calculate loss
# - We are calculating mean squared error

# %%
@tf.function
def loss(y_actual,y_predicted):
  diff=y_actual-y_predicted
  sqr=tf.square(diff)
  avg=tf.reduce_mean(sqr)
  return avg

# %% [markdown]
# ## Question 9

# %% [markdown]
# ### Define a function to train the model
# 1.   Record all the mathematical steps to calculate Loss
# 2.   Calculate Gradients of Loss w.r.t weights and bias
# 3.   Update Weights and Bias based on gradients and learning rate to minimize loss

# %%
def train(X,y_actual,w,b,learning_rate=0.01):
  with tf.GradientTape() as t:
    t.watch([w,b])
    current_prediction=prediction(X,w,b)
    current_loss=loss(y_actual,current_prediction)

  dw,db=t.gradient(current_loss,[w,b])  

  w=w-learning_rate *dw
  b=b-learning_rate *db

  return w,b

# %% [markdown]
# ## Question 10

# %% [markdown]
# ### Train the model for 100 epochs
# - Observe the training loss at every iteration

# %%
for i in range(100):
  W,b=train(X,Y,w,b)
  print('Current Training loss on iteration',i,loss(Y,prediction(X,w,b)).numpy())
# Out:
# Current Training loss on iteration 0 236.1682
# Current Training loss on iteration 1 235.09424
# Current Training loss on iteration 2 234.06282
# Current Training loss on iteration 3 233.07217
# Current Training loss on iteration 4 232.12048
# Current Training loss on iteration 5 231.20685
# Current Training loss on iteration 6 230.32932
# Current Training loss on iteration 7 229.48653
# Current Training loss on iteration 8 228.67712
# Current Training loss on iteration 9 227.89975
# Current Training loss on iteration 10 227.15286
# Current Training loss on iteration 11 226.43588
# Current Training loss on iteration 12 225.74736
# Current Training loss on iteration 13 225.08597
# Current Training loss on iteration 14 224.45088
# Current Training loss on iteration 15 223.84048
# Current Training loss on iteration 16 223.25485
# Current Training loss on iteration 17 222.69215
# Current Training loss on iteration 18 222.15169
# Current Training loss on iteration 19 221.63264
# Current Training loss on iteration 20 221.13428
# Current Training loss on iteration 21 220.65576
# Current Training loss on iteration 22 220.19585
# Current Training loss on iteration 23 219.75436
# Current Training loss on iteration 24 219.33017
# Current Training loss on iteration 25 218.92294
# Current Training loss on iteration 26 218.53174
# Current Training loss on iteration 27 218.15622
# Current Training loss on iteration 28 217.79533
# Current Training loss on iteration 29 217.44899
# Current Training loss on iteration 30 217.11607
# Current Training loss on iteration 31 216.79651
# Current Training loss on iteration 32 216.48982
# Current Training loss on iteration 33 216.19489
# Current Training loss on iteration 34 215.91154
# Current Training loss on iteration 35 215.63986
# Current Training loss on iteration 36 215.37874
# Current Training loss on iteration 37 215.128
# Current Training loss on iteration 38 214.88713
# Current Training loss on iteration 39 214.65572
# Current Training loss on iteration 40 214.43373
# Current Training loss on iteration 41 214.22023
# Current Training loss on iteration 42 214.0154
# Current Training loss on iteration 43 213.81854
# Current Training loss on iteration 44 213.6296
# Current Training loss on iteration 45 213.44804
# Current Training loss on iteration 46 213.27373
# Current Training loss on iteration 47 213.10632
# Current Training loss on iteration 48 212.94554
# Current Training loss on iteration 49 212.79124
# Current Training loss on iteration 50 212.64282
# Current Training loss on iteration 51 212.50015
# Current Training loss on iteration 52 212.36365
# Current Training loss on iteration 53 212.23215
# Current Training loss on iteration 54 212.10602
# Current Training loss on iteration 55 211.98474
# Current Training loss on iteration 56 211.8684
# Current Training loss on iteration 57 211.75655
# Current Training loss on iteration 58 211.64912
# Current Training loss on iteration 59 211.5461
# Current Training loss on iteration 60 211.44708
# Current Training loss on iteration 61 211.35202
# Current Training loss on iteration 62 211.2608
# Current Training loss on iteration 63 211.17296
# Current Training loss on iteration 64 211.08884
# Current Training loss on iteration 65 211.0078
# Current Training loss on iteration 66 210.9302
# Current Training loss on iteration 67 210.85562
# Current Training loss on iteration 68 210.78381
# Current Training loss on iteration 69 210.71486
# Current Training loss on iteration 70 210.64893
# Current Training loss on iteration 71 210.5854
# Current Training loss on iteration 72 210.52455
# Current Training loss on iteration 73 210.46603
# Current Training loss on iteration 74 210.40956
# Current Training loss on iteration 75 210.35555
# Current Training loss on iteration 76 210.30376
# Current Training loss on iteration 77 210.25398
# Current Training loss on iteration 78 210.20612
# Current Training loss on iteration 79 210.16016
# Current Training loss on iteration 80 210.11621
# Current Training loss on iteration 81 210.07364
# Current Training loss on iteration 82 210.03302
# Current Training loss on iteration 83 209.99382
# Current Training loss on iteration 84 209.95627
# Current Training loss on iteration 85 209.92027
# Current Training loss on iteration 86 209.88582
# Current Training loss on iteration 87 209.85231
# Current Training loss on iteration 88 209.82051
# Current Training loss on iteration 89 209.7897
# Current Training loss on iteration 90 209.76025
# Current Training loss on iteration 91 209.73192
# Current Training loss on iteration 92 209.7049
# Current Training loss on iteration 93 209.67899
# Current Training loss on iteration 94 209.6536
# Current Training loss on iteration 95 209.62973
# Current Training loss on iteration 96 209.60645
# Current Training loss on iteration 97 209.58423
# Current Training loss on iteration 98 209.56282
# Current Training loss on iteration 99 209.54248

# %% [markdown]
# ### Observe values of Weight
# - Print the updated values

# %%
print(w)
# Out:
# tf.Tensor(
# [[0.]
#  [0.]
#  [0.]
#  [0.]], shape=(4, 1), dtype=float32)

# %% [markdown]
# ### Observe values of Bias
# - Print the updated values

# %%
print(b)
# Out:
# tf.Tensor([4.609452], shape=(1,), dtype=float32)
